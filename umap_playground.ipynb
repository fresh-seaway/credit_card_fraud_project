# %%
import pandas as pd

df = pd.read_csv("creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
import umap

reducer = umap.UMAP(random_state=42)
reducer.fit(df.drop("Class", axis=1))
# Out:
# /home/dshebb/miniconda3/envs/py-3.12/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 import umap
#       3 reducer = umap.UMAP(random_state=42)
# ----> 4 reducer.fit(df.drop("Class", axis=1))
#
# File ~/miniconda3/envs/py-3.12/lib/python3.12/site-packages/umap/umap_.py:2817, in UMAP.fit(self, X, y, force_all_finite, **kwargs)
#    2813 if self.transform_mode == "embedding":
#    2814     epochs = (
#    2815         self.n_epochs_list if self.n_epochs_list is not None else self.n_epochs
#    2816     )
# -> 2817     self.embedding_, aux_data = self._fit_embed_data(
#    2818         self._raw_data[index],
#    2819         epochs,
#    2820         init,
# ...
